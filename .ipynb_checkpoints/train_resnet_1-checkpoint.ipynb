# %%
import warnings
warnings.simplefilter('ignore')

# %%
from model_1 import *
from model_1 import Net1

# %%
# Training parameter
num_epochs = 1           
batch_size = 16          
seed = np.random.seed(1234)

# %%
use_cuda = torch.cuda.is_available()

if use_cuda:
    computing_device = torch.device("cuda")
    extras = {"num_workers": 1, "pin_memory": True}
    print("CUDA is supported")
else: 
    computing_device = torch.device("cpu")
    extras = False
    print("CUDA NOT supported")
# Out:
# CUDA is supported

# %%
transform = transforms.Compose([transforms.Resize(512), transforms.ToTensor()])
train_loader, val_loader, test_loader = create_split_loaders(batch_size, seed, transform = transform, 
                                                             p_val = 0.1, p_test = 0.2,
                                                             shuffle = True, show_sample = False, 
                                                             extras = extras)

# %%
from loss import *

model = Net1()
model = model.to(computing_device)

criterion =  weighted_focal_loss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)

# %%
total_loss = []
avg_minibatch_loss = []

for epoch in range(num_epochs):
    N = 50
    N_minibatch_loss = 0.0 
    for minibatch_count, (images, labels) in enumerate(train_loader, 0):

        images, labels = images.to(computing_device), labels.to(computing_device)
        optimizer.zero_grad()
        outputs = model(images) # forward pass
        loss = criterion(outputs, labels) # compute loss
        loss.backward() # backprop
        optimizer.step() # weight update

        total_loss.append(loss.item())
        N_minibatch_loss += loss
        
        if (minibatch_count + 1) % N == 0:      
            N_minibatch_loss /= N
            print('Epoch: %d ! Average minibatch %d loss: %.3f' %
                (epoch + 1, minibatch_count + 1, N_minibatch_loss))
            avg_minibatch_loss.append(N_minibatch_loss)
            N_minibatch_loss = 0.0

    print("Finished", epoch + 1, "epochs of training")
print("Training complete after", epoch, "epochs")
# Out:
# Epoch: 1 ! Average minibatch 50 loss: 1.379
# Epoch: 1 ! Average minibatch 100 loss: 1.328
# Epoch: 1 ! Average minibatch 150 loss: 1.301
# Epoch: 1 ! Average minibatch 200 loss: 1.308
# Epoch: 1 ! Average minibatch 250 loss: 1.295
# Epoch: 1 ! Average minibatch 300 loss: 1.291
# Epoch: 1 ! Average minibatch 350 loss: 1.286
# Epoch: 1 ! Average minibatch 400 loss: 1.279
# Epoch: 1 ! Average minibatch 450 loss: 1.287
# Epoch: 1 ! Average minibatch 500 loss: 1.286
# Epoch: 1 ! Average minibatch 550 loss: 1.288
# Epoch: 1 ! Average minibatch 600 loss: 1.274
# Epoch: 1 ! Average minibatch 650 loss: 1.305
# Epoch: 1 ! Average minibatch 700 loss: 1.287
# Epoch: 1 ! Average minibatch 750 loss: 1.305
# Epoch: 1 ! Average minibatch 800 loss: 1.288
# Epoch: 1 ! Average minibatch 850 loss: 1.279
# Epoch: 1 ! Average minibatch 900 loss: 1.270
# Epoch: 1 ! Average minibatch 950 loss: 1.286
# Epoch: 1 ! Average minibatch 1000 loss: 1.278
# Finished 1 epochs of training
# Training complete after 0 epochs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.ylabel('Average minibatch loss')
plt.xlabel('Minibatch')
plt.plot(avg_minibatch_loss)
plt.savefig('Plots/fig_2_1.png')
plt.show()

# %%
plt.ylabel('Total loss')
plt.xlabel('Iterations')
plt.plot(total_loss)
plt.savefig('Plots/fig_2_2.png')
plt.show()

# %%
from test import *
from test import Test_Model

# %%
labels_all = []
predictions_all = []
model.eval()
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images, labels = images.to(computing_device), labels.to(computing_device)
        labels_all.append(labels)
        output = model(images)
        predictions = output > 0.5
        predictions_all.append(predictions)

labels = torch.cat(labels_all, 0)
predctions = torch.cat(predictions_all, 0)
test_res = Test_Model(predctions.float(), labels)
test_res.test_mod()
# Out:
# Classwise statistics:
# Accuracy:  tensor([0.7339, 0.9153, 0.6781, 0.3342, 0.9658, 0.9477, 0.9896, 0.8385, 0.9306,
#         0.9869, 0.9792, 0.9745, 0.9663, 0.9988], device='cuda:0',
#        dtype=torch.float64)
# Precision:  tensor([0.1668, 0.1314, 0.1661, 0.1696, 0.0000, 0.0000, 0.0000, 0.0697, 0.1043,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000], device='cuda:0',
#        dtype=torch.float64)
# Recall:  tensor([0.4304, 0.2571, 0.6339, 0.9119, 0.0000, 0.0000, 0.0000, 0.2532, 0.1126,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000], device='cuda:0',
#        dtype=torch.float64)
# BCR:  tensor([0.2986, 0.1943, 0.4000, 0.5407, 0.0000, 0.0000, 0.0000, 0.1614, 0.1084,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000], device='cuda:0',
#        dtype=torch.float64)
# Overall statistics:
# Average accuracy:  tensor(0.8742, device='cuda:0', dtype=torch.float64)
# Average precision:  tensor(0.0577, device='cuda:0', dtype=torch.float64)
# Average recall:  tensor(0.1856, device='cuda:0', dtype=torch.float64)
# Average BCR:  tensor(0.1217, device='cuda:0', dtype=torch.float64)
